# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Image, HTML
# %matplotlib notebook
matplotlib.style.use('ggplot')

# %% [markdown]
# # Introduction to Scientific Programming in Python
#
# ## What is Python, and How Do I Get It?

# %% [markdown]
# # Python is a General-Purpose Scripting Language
#
# ### General Purpose
#   - Meant for Performing a wide variety of Tasks in the Same Environment
#   - Code Complexity doesn't change when your task changes
#
# ### Scripting Language
#   - Code compiles down to additional intermediate programming languages before running.
#     - Makes code slower, but easier to read and write
#     - (Aside: CPython vs Jython vs PyPy)

# %% [markdown]
# # Quick Aside: Python vs Matlab
# Matlab is a more unified package, while Python has lots of disparate parts that must be learned separately.  This will slow us down in the beginning of the course, but by the end we'll see that the flexibility of Python makes it an effective tool. (For More info on Matlab v Python, please see http://www.pyzo.org/_images/pythonvsmatlab.png)

# %%
Image(url='http://www.pyzo.org/_images/pythonvsmatlab.png', width=800)
# Out:
# <img src="http://www.pyzo.org/_images/pythonvsmatlab.png" width="800"/>

# %% [markdown]
# # Scientific Programming is Mostly About Working with Data
#   - Collecting Data
#   - Accessing Data
#   - Organizing Data
#   - Transforming Data
#   - Interpreting Data
#     - Through Data Visualization (charts, graphs)
#     - Through Statistical Analysis

# %% [markdown]
# # In This Introductory Course, We'll Mostly Focus on These Tasks:
#   - Collecting Data
#   - **Accessing Data**
#   - **Organizing Data**
#   - Transforming Data
#   - **Interpreting Data**
#     - **Through Data Visualization (charts, graphs)**
#     - Through Statistical Analysis

# %% [markdown]
# # Installing Specific Packages
#
# (details to come)

# %% [markdown]
# # Development Tools: IPython and Jupyter Notebook

# %% [markdown]
# # IPython ("Interactive Python")
#
# IPython is a Full-Featured interactive console for Python.  To use it, open a command-line console on the  (aka its "terminal", or its "command window") and type in: **```ipython```**.  Everything you type in once the program is started will be python code, making it great for testing things out.  (Documentation can be found at https://ipython.org/ipython-doc/2/interactive/tutorial.html)

# %%
Image('ipython_console.png')

# %% [markdown]
# # The Notebook (aka IPython Notebook, Jupyter Notebook)
# All the activities in this course will be done on **Notebooks**.  This is a program that lets you type in code and run Python like any text editor, but does it in a way that encourages putting nice text descriptions, graphics, and even interactive features all together next to your code.  It's a great way to get started with scientific programming, and by the end of the course you'll be very familiar with all of its ins and outs.

# %%
Image(url='http://jupyter.org/assets/jupyterpreview.png', width=800)
# Out:
# <img src="http://jupyter.org/assets/jupyterpreview.png" width="800"/>

# %% [markdown]
# ## Starting Jupyter Notebook
#   1. In the console, type ```jupyter notebook``` (or maybe ```ipython notebook```).  This will start the notebook server.
#   2. Open a web browser, like Chrome or Firefox (Microsoft Edge may not be best) and go to the address listed in the console's message (probably something like **localhost:8888**)
#   3. Open a New Notebook at the Home Page that appears.
#   4. You're in!  The areas where you can type are called **cells** and let you either type code (**code cell**) or normal text (**Markdown cell**).  To run the code or render the text, press the run button or Ctrl-Enter.
#     - Text is formatted using Markdown.  To learn Markdown: https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet

# %% [markdown]
# # Python Variables and Variable Types

# %%
a_int = 3
a_float = 4.4
a_bool = True
a_str = 'hello'
a_list = [1, 2.4, 'goodbye']
a_tuple = (4, 3.5, 'dog', 'cat')
a_dict = {1: 5, 'a': 2, 'b': 'cat', 'dog': 8}
a_set = {1, 1, 2}

# %%
type(a_str)
# Out:
# str

# %% [markdown]
# ## All **Instances** of **Types** can be formed with a **Constructor**

# %%
b_int = int(3)
b_float = float(6.3)
b_str = str('hi')
b_list = list([1, 2, 3])
b_tuple = tuple([1,2,3])

c_int = int(b_float)

# %%
s = int('5')
s
# Out:
# 5

# %% [markdown]
# ## Operators (ex: +, -, /, * ) Do Different Things to Different Types

# %%
3 + 5
# Out:
# 8

# %%
7 / 2.6
# Out:
# 2.692307692307692

# %%
print('Hi' * 5)
['Hi'] * 5
# Out:
# HiHiHiHiHi
# ['Hi', 'Hi', 'Hi', 'Hi', 'Hi']

# %% [markdown]
# # Advanced Features

# %% [markdown]
# ## Tuple Unpacking

# %%
a, (b, c) = (1, (3, 5))
a, b = b, a
a, b
# Out:
# (3, 1)

# %% [markdown]
# ## Assignment with Operators

# %%
a = 5
a = a + 2
a
# Out:
# 10

# %% [markdown]
# # Bool Rules: 0 and Empty are False, all else are True

# %%
bool(3)
bool(-4.2)
bool("")
bool(['a', 'b', 'c'])
# Out:
# True

# %%
bool(0)
bool(0.0)
bool('')
bool([])
# Out:
# False

# %% [markdown]
# # Python is an "Object-Oriented" Language
#
#   - This means that everything in Python is has functions and data inside of it, viewable using the **dir()** function or pressing Tab in IPython.
#   - **Note:** Ignore everything beginning with __ (ex: '____add__').  These are "private".
#
# ## Essential Function: type()

# %%
print(dir('helo'))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %% [markdown]
# # Python is a "Dynamically Typed" Language
#
#   - This means that, unlike in other languages, you can change the type of a variable at any time you wish.
#   - To check that a variable is a certain type, use the **isinstance()** function or compare types directly

# %%
a = 3
print(  isinstance(a, str)   )
print(  type('Hello') == str  )
# Out:
# False
# True

# %% [markdown]
# ## Exercise: Find the Type of variable obtained from dividing an int by a float

# %% [markdown]
# # More OOP Jargon
#
#   - **Class** is the **type** of a variable.
#   - **Instance** is a **constructed** variable of that class.
#       - Often, people will call the instance an **object**, although this isn't technically correct.
#   - **Attribute** or **Property** is data that belongs to an object.
#       - In Python, this is accessed via the **dot (.)**
#       - ex) my_float.real
#   - **Method** is a **Function** that belongs to an object.
#       - In Python, you **call** functions with the **parentheses**.
#       - ex) 'Hello'.upper()
#
# ### In Python, Everything is an Object (to be explored)

# %% [markdown]
# # Read the Documentation!
#
# To understand what an object can do and how to use it, you have many possible sources of information:
#
#   1. The Package's Documentation itself.
#   2. The **help()** function
#   3. In IPython, the ?.
#      - Ex) sorted?
#   4. In IPython, the Tab button after the dot.
#   5. The **dir()** function.

# %% [markdown]
# # Essential String Methods

# %%
example_string = 'Mary had a little lamb named Sue.'
big_string = example_string.upper()

# %%
example_string.upper()
# Out:
# 'MARY HAD A LITTLE LAMB NAMED SUE.'

# %%
example_string.find('a', 2, 5)
# Out:
# -1

# %% [markdown]
# ### 5-Min Exercise: Find Out What the following methods do, and how to use them!

# %%
print( example_string.capitalize() )
example_string = example_string.replace('a', 'T')
print(example_string)
example_string.count
example_string.isalpha
example_string.isdigit
example_string.islower
print(example_string.split(' '))
'/'.join(['a', 'cat', 'is'])
# Out:
# Mtry htd t little ltmb ntmed sue.
# MTry hTd T little lTmb nTmed Sue.
# ['MTry', 'hTd', 'T', 'little', 'lTmb', 'nTmed', 'Sue.']
# 'a/cat/is'

# %% [markdown]
# # Essential List Methods

# %%
example_list = ['Python', 'Science', 'Awesome']

new_list = example_list.reverse()
print(new_list)
example_list.append
example_list.extend
example_list.sort
example_list.remove
example_list.pop
example_list.count
# Out:
# None
# <function list.count>

# %% [markdown]
# # Homework
#
#   1. Finish Codeacademy Tutorial!
#   2. Get Everything running on your Laptop
#
# Extra Challenge:  http://www.codewars.com
#
# This Script can be Downloaded at https://github.com/neuroneuro15/SciPyCourse2016

# %% [markdown]
# # Quick Review

# %% [markdown]
#   - What are some good reasons to use Python?

# %% [markdown]
#   - How do you find out what **class** a variable belongs to?

# %% [markdown]
#   - How do you get more information about an object?

# %% [markdown]
# # Extra Exploration: "Everything is an Object"

# %%
import math
type(math)
# Out:
# module

# %%
a = 3
type(3)
# Out:
# int

# %%
type(max)
# Out:
# builtin_function_or_method

# %%
type(int)
# Out:
# type

# %%
type(type)
# Out:
# type

# %% [markdown]
# # if - elif - else Statements
#  - **>**: "is greater than",   **<**: "is less than",
#  - **==**: "is equal to,  **!=**: "is *not* equal to"

# %%
a = 3
b = 10

# %%
if a > b:
    print('True')
else:
    print('False')
# Out:
# False

# %% [markdown]
# ## Aside: Python and "Meaningful Whitespace"
#   - Mixing spaces and tabs will result in errors!
#   - Same number of spaces on every line!
#   - Rule: If there's a colon, you must indent
